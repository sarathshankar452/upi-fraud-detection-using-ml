# %% [markdown]
# # BUILDING THE TRAINED MODEL

# %% [markdown]
# DATA PREPROCESSING

# %%
import pandas as pd

# %%
dataset = pd.read_csv('../dataset/upi_fraud_dataset.csv', index_col = 0)

# %%
dataset.head()
# Out:
#    trans_hour  trans_day  trans_month  trans_year  category  upi_number  age  \
# 0           0          1            1        2022        12  9957000001   54
# 1           1          1            1        2022         3  9957000002   15
# 2           3          1            1        2022         8  9957000003   60
# 3           6          1            1        2022         4  9957000004   44
# 4           6          1            1        2022         0  9957000005   72
#
#    trans_amount  state    zip  fraud_risk
# 0         66.21     22  49879           0
# 1         55.81     14  62668           0
# 2          8.68      4  96037           0
# 3         89.52     40  29911           0
# 4          1.90     38  16421           0

# %%
import numpy as np

# %%
x = dataset.iloc[ : , : 10].values
y = dataset.iloc[ : , 10].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, random_state = 0)

# %%
x_train.shape
# Out:
# (2266, 10)

# %%
x_test.shape
# Out:
# (400, 10)

# %%
fraud = np.count_nonzero(y_train == 1)
valid = np.count_nonzero(y_train == 0)

# %%
print('Fraud cases in training data =', fraud)
print('Valid cases in training data =', valid)
# Out:
# Fraud cases in training data = 1348
# Valid cases in training data = 918

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train[ : 5]
# Out:
# array([[ 1.11287494,  0.23492331, -0.89608107,  0.        ,  0.0602433 ,
#          0.68096147,  0.83994401, -0.84340161, -0.45791225, -1.64639185],
#        [-1.1894848 , -0.92886509,  0.66178275,  0.        , -1.24483613,
#         -0.3824002 , -0.27301162, -0.83469894,  1.03866827, -0.4058421 ],
#        [ 1.11287494, -1.02584746,  2.53121934,  0.        ,  0.32125918,
#         -0.38240085,  1.63491233,  1.40609705, -0.31538077,  0.32896382],
#        [-1.1894848 ,  0.91379987, -0.89608107,  0.        , -1.24483613,
#         -1.11969157, -0.3790074 , -0.72010938, -0.24411503,  0.5966091 ],
#        [ 1.11287494,  0.42888804, -0.89608107,  0.        , -1.76686789,
#         -1.11969169, -0.8029905 ,  0.14610555,  1.18119975,  1.37176053]])

# %%
x_test[ : 5]
# Out:
# array([[ 0.99775696, -1.02584746,  0.66178275,  0.        , -1.50585201,
#         -0.38240103, -0.8029905 , -0.55231661, -0.24411503,  0.60587057],
#        [-1.30460278,  1.6896588 , -0.89608107,  0.        , -0.72280436,
#         -0.93972315,  0.09797359, -0.10066076, -1.66942982,  1.78976412],
#        [-1.07436681,  0.33190567, -0.27293554,  0.        , -1.24483613,
#         -0.38240071, -0.96198416, -0.63173177,  0.46854236, -1.33247671],
#        [ 0.53728501, -1.21981219,  0.66178275,  0.        ,  1.10430683,
#          1.8381786 ,  0.94593979,  1.36440214, -0.24411503,  0.62521842],
#        [ 0.07681306, -1.02584746, -0.27293554,  0.        , -0.20077259,
#         -0.38240113, -0.22001374, -0.63409578, -0.67170947,  0.8568677 ]])

# %% [markdown]
# LOGISTIC REGRESSION (LR)

# %%
from sklearn.linear_model import LogisticRegression
LR_model = LogisticRegression(random_state = 0)
LR_model.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = LR_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc_lr = accuracy_score(y_test, y_pred)

# %%
print(acc_lr)
# Out:
# 0.8025

# %% [markdown]
# K-NEAREST NEIGHBORS (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN_model = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
KNN_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = KNN_model.predict(x_test)

# %%
acc_knn = accuracy_score(y_test, y_pred)

# %%
print(acc_knn)
# Out:
# 0.83

# %% [markdown]
# SUPPORT VECTOR MACHINE (SVM)

# %%
from sklearn.svm import SVC
SVM_model = SVC(kernel = 'linear', random_state = 0)
SVM_model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = SVM_model.predict(x_test)

# %%
acc_svm = accuracy_score(y_test, y_pred)

# %%
print(acc_svm)
# Out:
# 0.815

# %% [markdown]
# NAIVE BAYES (NB)

# %%
from sklearn.naive_bayes import GaussianNB
NB_model = GaussianNB()
NB_model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = NB_model.predict(x_test)

# %%
acc_nb = accuracy_score(y_test, y_pred)

# %%
print(acc_nb)
# Out:
# 0.8125

# %% [markdown]
# DECISION TREE (DT)

# %%
from sklearn.tree import DecisionTreeClassifier
DT_model = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
DT_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = DT_model.predict(x_test)

# %%
acc_dt = accuracy_score(y_test, y_pred)

# %%
print(acc_dt)
# Out:
# 0.9475

# %% [markdown]
# RANDOM FOREST (RF)

# %%
from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier()
RF_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = RF_model.predict(x_test)

# %%
acc_rf = accuracy_score(y_test, y_pred)

# %%
print(acc_rf)
# Out:
# 0.955

# %% [markdown]
# CONVOLUTIONAL NEURAL NETWORK (CNN)

# %%
import tensorflow as tf

# %%
CNN_model = tf.keras.models.Sequential()

# %%
CNN_model.add(tf.keras.layers.Dense(64, input_dim = 10, activation = 'relu'))
CNN_model.add(tf.keras.layers.Dense(128, activation = 'relu'))
CNN_model.add(tf.keras.layers.Dense(1, activation = 'sigmoid'))
# Out:
# c:\Users\sarat\OneDrive\Desktop\upi_fraud_detection\venv\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
CNN_model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
CNN_model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6845 - loss: 0.5542
# Epoch 2/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8080 - loss: 0.4067
# Epoch 3/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8279 - loss: 0.3675
# Epoch 4/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8425 - loss: 0.3431
# Epoch 5/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8491 - loss: 0.3262
# Epoch 6/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8570 - loss: 0.3177
# Epoch 7/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8597 - loss: 0.3079
# Epoch 8/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 0.3033
# Epoch 9/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8716 - loss: 0.3018
# Epoch 10/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8729 - loss: 0.2918
# Epoch 11/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.2903
# Epoch 12/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8747 - loss: 0.2881
# Epoch 13/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.2838
# Epoch 14/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8808 - loss: 0.2828
# Epoch 15/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8839 - loss: 0.2763
# Epoch 16/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8760 - loss: 0.2769
# Epoch 17/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0268
# Epoch 161/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0278
# Epoch 162/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0189
# Epoch 163/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9956 - loss: 0.0234
# Epoch 164/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9951 - loss: 0.0236
# Epoch 165/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0193
# Epoch 166/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9969 - loss: 0.0182
# Epoch 167/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0166
# Epoch 168/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0170
# Epoch 169/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9894 - loss: 0.0349
# Epoch 170/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9934 - loss: 0.0246
# Epoch 171/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9965 - loss: 0.0223
# Epoch 172/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9978 - loss: 0.0170
# Epoch 173/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0141
# Epoch 174/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0149
# Epoch 175/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0164
# Epoch 176/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9982 - loss: 0.0151
# Epoch 177/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0194
# Epoch 178/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0161
# Epoch 179/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9982 - loss: 0.0138
# Epoch 180/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.0120
# Epoch 181/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0197
# Epoch 182/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0142
# Epoch 183/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0125
# Epoch 184/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9965 - loss: 0.0177
# Epoch 185/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0161
# Epoch 186/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.0137
# Epoch 187/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0113
# Epoch 188/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0102
# Epoch 189/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0126
# Epoch 190/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0107
# Epoch 191/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 192/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 193/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9965 - loss: 0.0168
# Epoch 194/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0123
# Epoch 195/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0153
# Epoch 196/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 197/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9947 - loss: 0.0177
# Epoch 198/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9974 - loss: 0.0145
# Epoch 199/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0112
# Epoch 200/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9982 - loss: 0.0122

# %%
loss, acc_cnn = CNN_model.evaluate(x_train, y_train, verbose = 0)

# %%
print(acc_cnn)
# Out:
# 1.0

# %%
y_pred = CNN_model.predict(x_test)
y_pred[y_pred <= 0.5] = 0
y_pred[y_pred > 0.5] = 1
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ACCURACY COMPARISON OF ALL THE MODELS

# %%
scores = [acc_lr * 100,
          acc_knn * 100,
          acc_svm * 100,
          acc_nb * 100,
          acc_dt * 100,
          acc_rf * 100,
          acc_cnn * 100]

# %%
names = ["Logistic Regression",
        "K-Nearest Neighbors",
        "Support Vector Machine",
        "Naive Bayes",
        "Decision Tree",
        "Random Forest",
        "Convolutional Neural Network"]

# %%
df = pd.DataFrame()
df['Algorithm Name'] = names
df['Accuracy Score (%)'] = scores
df = df.sort_values('Accuracy Score (%)', ascending = False)

# %%
df
# Out:
#                  Algorithm Name  Accuracy Score (%)
# 6  Convolutional Neural Network              100.00
# 5                 Random Forest               95.50
# 4                 Decision Tree               94.75
# 1           K-Nearest Neighbors               83.00
# 2        Support Vector Machine               81.50
# 3                   Naive Bayes               81.25
# 0           Logistic Regression               80.25

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig = plt.subplots(figsize = (10, 5))
ax = sns.barplot(x = "Accuracy Score (%)", y = "Algorithm Name", data = df)

# %% [markdown]
# SAVING THE BEST TRAINED MODEL

# %%
import os.path

# %%
if os.path.isfile('../model/project_model1.h5') is False:
    CNN_model.save('../model/project_model1.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
