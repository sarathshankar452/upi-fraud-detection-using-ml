# %% [markdown]
# # BUILDING THE TRAINED MODEL

# %% [markdown]
# DATA PREPROCESSING

# %%
import pandas as pd

# %%
dataset = pd.read_csv(r'C:\Users\sarat\OneDrive\Desktop\upi_fraud_detection\upi_fraud_dataset.csv', index_col=0)

# %%
dataset.head()
# Out:
#     trans_hour  trans_day  trans_month  trans_year  category  upi_number  age  \
# Id
# 0            0          1            1        2026        12  8712362976   23
# 1            1          1            1        2022         3  9957000002   15
# 2            3          1            1        2022         8  9957000003   60
# 3            6          1            1        2022         4  9957000004   44
# 4            6          1            1        2022         0  9957000005   72
#
#     trans_amount  state     zip  fraud_risk
# Id
# 0          66.21     22  532185           0
# 1          55.81     14   62668           0
# 2           8.68      4   96037           0
# 3          89.52     40   29911           0
# 4           1.90     38   16421           0

# %%
import numpy as np

# %%
x = dataset.iloc[ : , : 10].values
y = dataset.iloc[ : , 10].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, random_state = 0)

# %%
x_train.shape
# Out:
# (2266, 10)

# %%
x_test.shape
# Out:
# (400, 10)

# %%
fraud = np.count_nonzero(y_train == 1)
valid = np.count_nonzero(y_train == 0)

# %%
print('Fraud cases in training data =', fraud)
print('Valid cases in training data =', valid)
# Out:
# Fraud cases in training data = 1348
# Valid cases in training data = 918

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train[ : 5]
# Out:
# array([[ 1.11287494,  0.23492331, -0.89608107, -0.02101193,  0.0602433 ,
#          0.70849928,  0.84042222, -0.84340161, -0.45791225, -1.54579454],
#        [-1.1894848 , -0.92886509,  0.66178275, -0.02101193, -1.24483613,
#         -0.37232103, -0.27220664, -0.83469894,  1.03866827, -0.38666328],
#        [ 1.11287494, -1.02584746,  2.53121934, -0.02101193,  0.32125918,
#         -0.37232169,  1.63515712,  1.40609705, -0.31538077,  0.2999166 ],
#        [-1.1894848 ,  0.91379987, -0.89608107, -0.02101193, -1.24483613,
#         -1.12171751, -0.37817129, -0.72010938, -0.24411503,  0.54999606],
#        [ 1.11287494,  0.42888804, -0.89608107, -0.02101193, -1.76686789,
#         -1.12171764, -0.80202991,  0.14610555,  1.18119975,  1.27427354]])

# %%
x_test[ : 5]
# Out:
# array([[ 0.99775696, -1.02584746,  0.66178275, -0.02101193, -1.50585201,
#         -0.37232188, -0.80202991, -0.55231661, -0.24411503,  0.55864969],
#        [-1.30460278,  1.6896588 , -0.89608107, -0.02101193, -0.72280436,
#         -0.93879431,  0.09866965, -0.10066076, -1.66942982,  1.66484314],
#        [-1.07436681,  0.33190567, -0.27293554, -0.02101193, -1.24483613,
#         -0.37232155, -0.96097689, -0.63173177,  0.46854236, -1.25248196],
#        [ 0.53728501, -1.21981219,  0.66178275, -0.02101193,  1.10430683,
#          1.88471602,  0.94638687,  1.36440214, -0.24411503,  0.57672772],
#        [ 0.07681306, -1.02584746, -0.27293554, -0.02101193, -0.20077259,
#         -0.37232198, -0.21922431, -0.63409578, -0.67170947,  0.79317363]])

# %% [markdown]
# LOGISTIC REGRESSION (LR)

# %%
from sklearn.linear_model import LogisticRegression
LR_model = LogisticRegression(random_state = 0)
LR_model.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = LR_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc_lr = accuracy_score(y_test, y_pred)

# %%
print(acc_lr)
# Out:
# 0.8025

# %% [markdown]
# K-NEAREST NEIGHBORS (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN_model = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
KNN_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = KNN_model.predict(x_test)

# %%
acc_knn = accuracy_score(y_test, y_pred)

# %%
print(acc_knn)
# Out:
# 0.8375

# %% [markdown]
# SUPPORT VECTOR MACHINE (SVM)

# %%
from sklearn.svm import SVC
SVM_model = SVC(kernel = 'linear', random_state = 0)
SVM_model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = SVM_model.predict(x_test)

# %%
acc_svm = accuracy_score(y_test, y_pred)

# %%
print(acc_svm)
# Out:
# 0.815

# %% [markdown]
# NAIVE BAYES (NB)

# %%
from sklearn.naive_bayes import GaussianNB
NB_model = GaussianNB()
NB_model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = NB_model.predict(x_test)

# %%
acc_nb = accuracy_score(y_test, y_pred)

# %%
print(acc_nb)
# Out:
# 0.575

# %% [markdown]
# DECISION TREE (DT)

# %%
from sklearn.tree import DecisionTreeClassifier
DT_model = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
DT_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = DT_model.predict(x_test)

# %%
acc_dt = accuracy_score(y_test, y_pred)

# %%
print(acc_dt)
# Out:
# 0.955

# %% [markdown]
# RANDOM FOREST (RF)

# %%
from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier()
RF_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = RF_model.predict(x_test)

# %%
acc_rf = accuracy_score(y_test, y_pred)

# %%
print(acc_rf)
# Out:
# 0.9525

# %% [markdown]
# CONVOLUTIONAL NEURAL NETWORK (CNN)

# %%
import tensorflow as tf

# %%
CNN_model = tf.keras.models.Sequential()

# %%
CNN_model.add(tf.keras.layers.Dense(64, input_dim = 10, activation = 'relu'))
CNN_model.add(tf.keras.layers.Dense(128, activation = 'relu'))
CNN_model.add(tf.keras.layers.Dense(1, activation = 'sigmoid'))
# Out:
# c:\Users\sarat\OneDrive\Desktop\upi_fraud_detection\venv\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
CNN_model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
CNN_model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0120
# Epoch 2/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9863 - loss: 0.0406
# Epoch 161/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9744 - loss: 0.0677
# Epoch 162/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9898 - loss: 0.0187
# Epoch 163/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0051
# Epoch 164/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 165/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 166/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9996 - loss: 0.0025
# Epoch 167/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0036
# Epoch 168/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 169/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9996 - loss: 0.0027
# Epoch 170/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 171/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 172/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.0040
# Epoch 173/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0066
# Epoch 174/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0028
# Epoch 175/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0047
# Epoch 176/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0038
# Epoch 177/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0096
# Epoch 178/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0080
# Epoch 179/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 180/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 181/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 182/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 183/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 184/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0079
# Epoch 185/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 186/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0057
# Epoch 187/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0087
# Epoch 188/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.0046
# Epoch 189/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0102
# Epoch 190/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0134
# Epoch 191/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0116
# Epoch 192/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0129
# Epoch 193/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0079
# Epoch 194/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 195/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 196/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 197/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 198/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 199/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.6907e-04
# Epoch 200/200
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0012

# %%
loss, acc_cnn = CNN_model.evaluate(x_train, y_train, verbose = 0)

# %%
print(acc_cnn)
# Out:
# 1.0

# %%
y_pred = CNN_model.predict(x_test)
y_pred[y_pred <= 0.5] = 0
y_pred[y_pred > 0.5] = 1
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ACCURACY COMPARISON OF ALL THE MODELS

# %%
scores = [acc_lr * 100,
          acc_knn * 100,
          acc_svm * 100,
          acc_nb * 100,
          acc_dt * 100,
          acc_rf * 100,
          acc_cnn * 100]

# %%
names = ["Logistic Regression",
        "K-Nearest Neighbors",
        "Support Vector Machine",
        "Naive Bayes",
        "Decision Tree",
        "Random Forest",
        "Convolutional Neural Network"]

# %%
df = pd.DataFrame()
df['Algorithm Name'] = names
df['Accuracy Score (%)'] = scores
df = df.sort_values('Accuracy Score (%)', ascending = False)

# %%
df
# Out:
#                  Algorithm Name  Accuracy Score (%)
# 6  Convolutional Neural Network              100.00
# 4                 Decision Tree               95.50
# 5                 Random Forest               95.25
# 1           K-Nearest Neighbors               83.75
# 2        Support Vector Machine               81.50
# 0           Logistic Regression               80.25
# 3                   Naive Bayes               57.50

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig = plt.subplots(figsize = (10, 5))
ax = sns.barplot(x = "Accuracy Score (%)", y = "Algorithm Name", data = df)

# %% [markdown]
# SAVING THE BEST TRAINED MODEL

# %%
import os.path

# %%
if os.path.isfile('../model/project_model.h5') is False:
    CNN_model.save('../model/project_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
